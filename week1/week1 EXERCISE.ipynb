# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
import os
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# set up environment
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'
OLLAMA_API_FOR_OPENAPI = 'http://localhost:11434/v1'

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key or not api_key.startswith('sk-proj-') or not len(api_key)>10:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")

openai = OpenAI()
ollama_via_openai = OpenAI(base_url=OLLAMA_API_FOR_OPENAPI, api_key='anything')

# %%
def get_messages(question: str):
    system_prompt = """
    You are my assistent to answer tech questions.
    Please explain why something is not working, what are possible reasons.
    Give examples how to fix issue.
    Also, provide external links at then end.
    Answer in Markdown format.
    """
    
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": question}
    ]

# %%
# Get gpt-4o-mini to answer, with streaming
def get_anwer_from_openai(question: str):
    stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=get_messages(question),
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)

    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        # response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
# Get Llama 3.2 to answer
def get_anwer_from_llama(question: str):
    response = ollama_via_openai.chat.completions.create(
        model=MODEL_LLAMA,
        messages=get_messages(question)
    )

    display(Markdown(response.choices[0].message.content))

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
get_anwer_from_openai(question)

# %%
get_anwer_from_llama(question)
